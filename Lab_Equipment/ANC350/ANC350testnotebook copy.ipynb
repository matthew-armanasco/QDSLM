# %%
import pyanc350

# %%
anc = pyanc350.v2.Positioner()
# Out:
# 1 ANC350 connected
# ANC350 with id: 125859416 has locked state: False
# connected to first positioner

# %%
print(anc.getPosition(0))
print(anc.getPosition(1))
print(anc.getPosition(2))
# Out:
# 2987944
# 2461355
# 750496

# %%
print(anc.getFrequency(0))
print(anc.getFrequency(1))
print(anc.getFrequency(2))
# Out:
# 100
# 1
# 1
